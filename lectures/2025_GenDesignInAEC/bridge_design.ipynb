# %%
# !pip install aixd
# Out:
# Collecting aixd
#   Downloading aixd-1.0.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pandas>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from aixd) (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.12/dist-packages (from aixd) (2.0.2)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from aixd) (1.16.2)
# Requirement already satisfied: scikit-learn>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from aixd) (1.6.1)
# Collecting plotly~=6.0.0 (from aixd)
#   Downloading plotly-6.0.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting kaleido<1.0.0 (from aixd)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Collecting torch<2.8,>=2.0.0 (from aixd)
#   Downloading torch-2.7.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from aixd) (0.22.1)
# Collecting pytorch-lightning<2.6,>=2.0.0 (from aixd)
#   Downloading pytorch_lightning-2.5.5-py3-none-any.whl.metadata (20 kB)
# Collecting bayesian-optimization<2.0.0 (from aixd)
#   Downloading bayesian_optimization-1.5.1-py3-none-any.whl.metadata (16 kB)
# Collecting coolname (from aixd)
#   Downloading coolname-2.2.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting colorama<0.5.0,>=0.4.6 (from bayesian-optimization<2.0.0->aixd)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.0->aixd) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.0->aixd) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.0->aixd) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly~=6.0.0->aixd) (2.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly~=6.0.0->aixd) (25.0)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning<2.6,>=2.0.0->aixd) (4.67.1)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning<2.6,>=2.0.0->aixd) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning<2.6,>=2.0.0->aixd) (2025.3.0)
# Collecting torchmetrics>0.7.0 (from pytorch-lightning<2.6,>=2.0.0->aixd)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning<2.6,>=2.0.0->aixd) (4.15.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning<2.6,>=2.0.0->aixd)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.23.0->aixd) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.23.0->aixd) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (3.19.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (12.6.80)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch<2.8,>=2.0.0->aixd)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (12.5.4.2)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch<2.8,>=2.0.0->aixd)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch<2.8,>=2.0.0->aixd)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<2.8,>=2.0.0->aixd) (1.11.1.6)
# Collecting triton==3.3.1 (from torch<2.8,>=2.0.0->aixd)
#   Downloading triton-3.3.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb->aixd) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->aixd) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->aixd) (4.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb->aixd) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb->aixd) (2.11.9)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->aixd) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->aixd) (2.39.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning<2.6,>=2.0.0->aixd) (3.12.15)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->aixd) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->aixd) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->aixd) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->aixd) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1.0->aixd) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb->aixd) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb->aixd) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb->aixd) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb->aixd) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<2.8,>=2.0.0->aixd) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<2.8,>=2.0.0->aixd) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.6,>=2.0.0->aixd) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.6,>=2.0.0->aixd) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.6,>=2.0.0->aixd) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.6,>=2.0.0->aixd) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.6,>=2.0.0->aixd) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.6,>=2.0.0->aixd) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.6,>=2.0.0->aixd) (1.20.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->aixd) (5.0.2)
# Downloading aixd-1.0.0-py2.py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.5/169.5 kB 9.9 MB/s eta 0:00:00
# Downloading bayesian_optimization-1.5.1-py3-none-any.whl (28 kB)
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.0 MB/s eta 0:00:00
# Downloading plotly-6.0.1-py3-none-any.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 47.4 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.5-py3-none-any.whl (832 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.4/832.4 kB 35.2 MB/s eta 0:00:00
# Downloading torch-2.7.1-cp312-cp312-manylinux_2_28_x86_64.whl (821.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.0/821.0 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 6.9 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 6.5 MB/s eta 0:00:00
# Downloading triton-3.3.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 8.1 MB/s eta 0:00:00
# Downloading coolname-2.2.0-py2.py3-none-any.whl (37 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 68.6 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, kaleido, coolname, triton, plotly, nvidia-nccl-cu12, nvidia-cudnn-cu12, lightning-utilities, colorama, torch, bayesian-optimization, torchmetrics, pytorch-lightning, aixd
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.7.1
#     Uninstalling nvidia-cusparselt-cu12-0.7.1:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
#   Attempting uninstall: triton
#     Found existing installation: triton 3.4.0
#     Uninstalling triton-3.4.0:
#       Successfully uninstalled triton-3.4.0
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.3
#     Uninstalling nvidia-nccl-cu12-2.27.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: torch
#     Found existing installation: torch 2.8.0+cu126
#     Uninstalling torch-2.8.0+cu126:
#       Successfully uninstalled torch-2.8.0+cu126
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.23.0+cu126 requires torch==2.8.0, but you have torch 2.7.1 which is incompatible.
# torchaudio 2.8.0+cu126 requires torch==2.8.0, but you have torch 2.7.1 which is incompatible.
# Successfully installed aixd-1.0.0 bayesian-optimization-1.5.1 colorama-0.4.6 coolname-2.2.0 kaleido-0.2.1 lightning-utilities-0.15.2 nvidia-cudnn-cu12-9.5.1.17 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 plotly-6.0.1 pytorch-lightning-2.5.5 torch-2.7.1 torchmetrics-1.8.2 triton-3.3.1

# %%
# Install torch, torchvision, torchaudio with CUDA 12.6 support
# !pip install torch==2.8.0+cu126 torchvision==0.23.0+cu126 torchaudio==2.8.0+cu126 --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Collecting torch==2.8.0+cu126
#   Downloading https://download.pytorch.org/whl/cu126/torch-2.8.0%2Bcu126-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Requirement already satisfied: torchvision==0.23.0+cu126 in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: torchaudio==2.8.0+cu126 in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (12.6.80)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch==2.8.0+cu126)
#   Downloading https://download.pytorch.org/whl/nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (12.5.4.2)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch==2.8.0+cu126)
#   Downloading https://download.pytorch.org/whl/nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.3 (from torch==2.8.0+cu126)
#   Downloading https://download.pytorch.org/whl/nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu126) (1.11.1.6)
# Collecting triton==3.4.0 (from torch==2.8.0+cu126)
#   Downloading https://download.pytorch.org/whl/triton-3.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision==0.23.0+cu126) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision==0.23.0+cu126) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.8.0+cu126) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.8.0+cu126) (3.0.3)
# Downloading https://download.pytorch.org/whl/cu126/torch-2.8.0%2Bcu126-cp312-cp312-manylinux_2_28_x86_64.whl (821.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.8/821.8 MB 2.1 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 2.5 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 5.0 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 4.2 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/triton-3.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 5.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, triton, nvidia-nccl-cu12, nvidia-cudnn-cu12, torch
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.6.3
#     Uninstalling nvidia-cusparselt-cu12-0.6.3:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.6.3
#   Attempting uninstall: triton
#     Found existing installation: triton 3.3.1
#     Uninstalling triton-3.3.1:
#       Successfully uninstalled triton-3.3.1
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.26.2
#     Uninstalling nvidia-nccl-cu12-2.26.2:
#       Successfully uninstalled nvidia-nccl-cu12-2.26.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.5.1.17
#     Uninstalling nvidia-cudnn-cu12-9.5.1.17:
#       Successfully uninstalled nvidia-cudnn-cu12-9.5.1.17
#   Attempting uninstall: torch
#     Found existing installation: torch 2.7.1
#     Uninstalling torch-2.7.1:
#       Successfully uninstalled torch-2.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aixd 1.0.0 requires torch<2.8,>=2.0.0, but you have torch 2.8.0+cu126 which is incompatible.
# Successfully installed nvidia-cudnn-cu12-9.10.2.21 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.3 torch-2.8.0+cu126 triton-3.4.0

# %% [markdown]
# ### 2. Synthetic Data Generation
#
# now we hand over the LHS sampled input feature value list to Rhino / GH to obtain performance values per design instance.
#
# now first do some inspection of the performance attribute values

# %%
import numpy as np
import pandas as pd
from scipy.stats import qmc

df_lhs = pd.read_csv("lhs_samples_results.csv")

df_lhs.describe()
# Out:
#            Nfrequ1      Nfrequ2      Nfrequ3   max_disp_cm        Mass_Kg  \
# count  1000.000000  1000.000000  1000.000000   1000.000000    1000.000000
# mean      1.863000     2.983400     4.302100    129.343545  193264.102000
# std       1.030909     1.554961     1.919497    673.520009   63868.629612
# min       0.100000     0.300000     0.400000      0.570000   76100.000000
# 25%       1.100000     1.775000     2.800000      2.565000  140660.000000
# 50%       1.600000     2.900000     4.300000      5.130000  191286.000000
# 75%       2.500000     3.700000     5.700000     16.530000  235166.750000
# max       7.800000     9.300000    11.400000  12111.075000  401078.000000
#
#        util_average
# count   1000.000000
# mean       2.242958
# std        5.739388
# min        0.207163
# 25%        0.488279
# 50%        0.763154
# 75%        1.412177
# max       86.297872

# %% [markdown]
# ### 3. Data set creation
#
# #### Define your design parameter and perfromance attributes

# %%
from aixd.data.data_blocks import DesignParameters, PerformanceAttributes
from aixd.data.data_objects import DataReal, DataInt, DataCategorical
from aixd.data.domain import Interval, Options

# Defining Design Parameter
obj_list = [
    DataReal(name="A", dim=1, domain = Interval(0.0, 5.0)),
    DataReal(name="mu", dim=1, domain = Interval(0.0, 1.0)),
    DataReal(name="sigma", dim=1, domain = Interval(0.05, 1.0)),
    DataInt(name="num_piers", dim=1, domain = Interval(1, 6)),
    DataReal(name="pier_h", dim=1, domain = Interval(-6.0, 0.0), unit="m"),
    DataReal(name="shell_cross_section", dim=1, domain = Interval(10.0, 30.0), unit="cm"),
    DataReal(name="pier_diameter", dim=1, domain = Interval(20.0, 60.0), unit="cm"),
    DataCategorical(name="Concrete", dim=1, domain = Options(["C30/37", "C40/50", "C60/75"])),
    ]

design_parameters = DesignParameters(name="design_parameters", dobj_list=obj_list)
# Out:
# /usr/local/lib/python3.12/dist-packages/aixd/data/domain.py:575: UserWarning: Expected to get an object of class <Interval> with type integer, but got type real instead. Creating a new domain object with type to integer.
#   warnings.warn(

# %% [markdown]
# And similar we define the performance attributes:

# %%
obj_list = [
    DataReal(name="Nfrequ1", dim=1, unit="Hz"),
    DataReal(name="Nfrequ2", dim=1, unit="Hz"),
    DataReal(name="Nfrequ3", dim=1, unit="Hz"),
    DataReal(name="max_disp_cm", dim=1, unit="cm"),
    DataReal(name="Mass_Kg", dim=1, unit="kg"),
    DataReal(name="util_average", dim=1, unit="-"),
]

performance_attributes = PerformanceAttributes(name="performance_attributes", dobj_list=obj_list)
# Out:
# /usr/local/lib/python3.12/dist-packages/aixd/data/data_objects.py:433: UserWarning: Expected to get an object of class <Interval> as a domain. One created automatically with range 0 to 100
#   warnings.warn("Expected to get an object of class <Interval> as a domain. One created automatically with range 0 to 100")

# %% [markdown]
# #### Create your dataset object
#
# Using the defined design parameters and performance attributes, we initialize the dataset object. Here we just define the structure of the data set, so far no actual data is saved in the data set. The function also creates a dataset folder in the directory of the notebook.

# %%
from aixd.data.dataset import Dataset

dataset = Dataset(root_path=None, name="Bridge_Design", design_par=design_parameters, perf_attributes=performance_attributes, overwrite=True)
# Out:
# [INFO - AIXD.dataset] Dataset object is saved at /content/Bridge_Design/dataset_object.json

# %% [markdown]
# #### Import data to your dataset object
#
# If we have data available we can directly import our data into the dataset from our dataframe. Here we save our data from the dataFrame to the dataset object we have created before.

# %%
# Load your two CSVs
df_samples = pd.read_csv("lhs_samples.csv")
df_results = pd.read_csv("lhs_samples_results.csv")

# Combine the two csv
df = pd.concat([df_samples.reset_index(drop=True), df_results.reset_index(drop=True)], axis=1)

# Save the combined dataset
df.to_csv("bridge_data_set.csv", index=False)

# Create the XAID dataset object
dataset.import_data_from_df(df)
# Out:
# [WARNING - AIXD.callbacks] Error column not found. Adding an all zero to the end
# [INFO - AIXD.dataset] 1000 design parameters imported and stored in design_parameters/dp_0000.pkl
# [INFO - AIXD.dataset] 1000 performance attributes imported and stored in performance_attributes/pa_0000.pkl
# [INFO - AIXD.dataset] Dataset object is saved at /content/Bridge_Design/dataset_object.json
# [INFO - AIXD.dataset] Data import finished. Updating range of performance attributes
# [INFO - AIXD.dataset] Loaded a total of 1000 samples from 1 files in 0.004787921905517578 seconds
# [INFO - AIXD.data-objects] * Updating domain for Nfrequ1: The domain spans the interval [0.0, 1.0], but the data spans the interval [0.1, 7.8] (floored/ceiled to 3 decimal). Updating the domain to match the data. The new domain is Interval(0.1, 7.8).
# [INFO - AIXD.data-objects] * Updating domain for Nfrequ2: The domain spans the interval [0.0, 1.0], but the data spans the interval [0.3, 9.3] (floored/ceiled to 3 decimal). Updating the domain to match the data. The new domain is Interval(0.3, 9.3).
# [INFO - AIXD.data-objects] * Updating domain for Nfrequ3: The domain spans the interval [0.0, 1.0], but the data spans the interval [0.4, 11.4] (floored/ceiled to 3 decimal). Updating the domain to match the data. The new domain is Interval(0.4, 11.4).
# [INFO - AIXD.data-objects] * Updating domain for max_disp_cm: The domain spans the interval [0.0, 1.0], but the data spans the interval [0.57, 12111.075] (floored/ceiled to 3 decimal). Updating the domain to match the data. The new domain is Interval(0.57, 12111.075).
# [INFO - AIXD.data-objects] * Updating domain for Mass_Kg: The domain spans the interval [0.0, 1.0], but the data spans the interval [76100.0, 401078.0] (floored/ceiled to 3 decimal). Updating the domain to match the data. The new domain is Interval(76100.0, 401078.0).
# [INFO - AIXD.data-objects] * Updating domain for util_average: The domain spans the interval [0.0, 1.0], but the data spans the interval [0.207, 86.298] (floored/ceiled to 3 decimal). Updating the domain to match the data. The new domain is Interval(0.207, 86.298).
# [INFO - AIXD.dataset] Dataset object is saved at /content/Bridge_Design/dataset_object.json

# %%
dataset.data["design_parameters"].head()
# Out:
#    uid         A        mu     sigma num_piers pier_h shell_cross_section  \
# 0    0   0.57113  0.195561  0.432034         1  -0.79                  24
# 1    1   4.56107  0.254872  0.803872         1  -4.97                  23
# 2    2  3.757783  0.747773  0.832273         6  -1.52                  18
# 3    3  1.123227  0.834029  0.720802         6  -2.75                  22
# 4    4  1.529229  0.096317  0.928042         1   -5.5                  12
#
#   pier_diameter Concrete
# 0            31   C30/37
# 1            45   C30/37
# 2            29   C30/37
# 3            40   C40/50
# 4            46   C40/50

# %%
dataset.data["performance_attributes"].head()
# Out:
#    uid Nfrequ1 Nfrequ2 Nfrequ3 max_disp_cm Mass_Kg util_average  error
# 0    0     1.0     1.3     2.0       71.82  184320     3.764846      0
# 1    1     1.0     1.4     3.5        11.4  312402     1.374871      0
# 2    2     2.3     3.6     5.7       2.565  220215     0.613419      0
# 3    3     2.5     4.3     6.2        0.57  184431     0.354233      0
# 4    4     1.0     1.2     2.5       35.91  105400      1.78484      0

# %%
dataset.update_obj_domains()
# Out:
# [INFO - AIXD.data-objects] * Updating domain for A: The domain spans the interval [0.0, 5.0], but the data spans the interval [0.003, 4.997] (floored/ceiled to 3 decimal). Updating the domain to match the data. The new domain is Interval(0.003, 4.997).
# [INFO - AIXD.data-objects] * Updating domain for mu: OK (no update)
# [INFO - AIXD.data-objects] * Updating domain for sigma: OK (no update)
# [INFO - AIXD.data-objects] * Updating domain for num_piers: The domain spans the interval [1, 6], but the data spans the interval [0.0, 6.0] (floored/ceiled to 3 decimal). Updating the domain to match the data. The new domain is Interval(0, 6).
# [INFO - AIXD.data-objects] * Updating domain for pier_h: The domain spans the interval [-6.0, 0.0], but the data spans the interval [-6.0, -0.01] (floored/ceiled to 3 decimal). Updating the domain to match the data. The new domain is Interval(-6.0, -0.01).
# [INFO - AIXD.data-objects] * Updating domain for shell_cross_section: OK (no update)
# [INFO - AIXD.data-objects] * Updating domain for pier_diameter: OK (no update)
# [INFO - AIXD.data-objects] * Updating domain for Concrete: OK (no update)
# [INFO - AIXD.data-objects] * Updating domain for Nfrequ1: OK (no update)
# [INFO - AIXD.data-objects] * Updating domain for Nfrequ2: OK (no update)
# [INFO - AIXD.data-objects] * Updating domain for Nfrequ3: OK (no update)
# [INFO - AIXD.data-objects] * Updating domain for max_disp_cm: OK (no update)
# [INFO - AIXD.data-objects] * Updating domain for Mass_Kg: OK (no update)
# [INFO - AIXD.data-objects] * Updating domain for util_average: OK (no update)
# [INFO - AIXD.dataset] Dataset object is saved at /content/Bridge_Design/dataset_object.json

# %% [markdown]
# ### 3. Data exploration
#
# Next we can use the data visualization functionalities of the plotter to understand our data. For that we need to set up our plotter object

# %%
from aixd.visualisation.plotter import Plotter

plotter = Plotter(dataset)
# Out:
# [INFO - AIXD.plotter]
# Plotter: Information
# --------------------
# The following block names and variable names are available as arguments for plotting methods:
#     Block "design_parameters" (Design Parameters):
#     -> Variables: "A", "mu", "sigma", "num_piers", "pier_h", "shell_cross_section", "pier_diameter", "Concrete"
#     Block "performance_attributes" (Performance Attributes):
#     -> Variables: "Nfrequ1", "Nfrequ2", "Nfrequ3", "max_disp_cm", "Mass_Kg", "util_average"
# Data from dataset blocks will be plotted in the original data domain.
# Data from datamodule blocks will be plotted in the transformed domain (if `transformed=True`) or in the original domain, but after transformations (if `transformed=False`).

# %% [markdown]
# Helpful is for example to visualize the individual aswell as the pair-wise variable distributions.

# %%
plotter.distrib_attributes(block="design_parameters", per_column=True, sub_figs=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="c6d45776-0e9f-4bca-93c4-a335f6ec9a67" class="plotly-graph-div" style="height:900px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c6d45776-0e9f-4bca-93c4-a335f6ec9a67")) {                    Plotly.newPlot(                        "c6d45776-0e9f-4bca-93c4-a335f6ec9a67",                        [{"marker":{"color":"#643264"},"name":"A","x":[0.5711302197572201,4.561069678473616,3.757782929005864,1.1232273701593507,1.529228552539662,1.9790526432045783,4.701498674489988,4.4043012375819535,4.847705421122308,3.90117500571292,0.7589270766359023,4.966690417426366,3.5948864396343305,1.9715183981246112,1.0744099704893977,2.716415549054205,2.7684702168792468,1.901863455796488,3.643350693938336,4.343265650977325,2.1925667083458094,2.8673966379876425,1.5244571212943228,4.750419940774312,4.578414305535886,0.8847754469030383,1.832405708198068,1.533687697420386,4.237003086042396,1.674280512487244,3.921528687821785,0.4743812309817483,3.49856776886559,2.9579044284034186,1.0699108160801152,1.7206613052311202,0.3777305155896185,4.957027831681218,4.09857639958831,3.7170442809194455,1.059782624689936,1.578131929307702,4.895782125242011,4.634327238957933,4.088667683412496,4.263362522177937,0.2383581939749765,2.1985592219290875,1.2695245212588502,2.4720315899776684,3.361919171499879,2.9460037764174403,0.6867106835747974,3.263647325295449,2.543
\u002fA72GMWpXoP5jQtHLlYuw\u002fAAAAAAAA8D9uKBVxMCrUvwxknk4g5dk\u002fzVXrNRRB3b\u002fNVB2xRcC1v+7tA8ryFaq\u002fcWQfZxxpwb8dSmqKZVDTv2e9jzceiou\u002f3mt1rSoetr+9V1x1BG6FPz8jFQg+FtK\u002fu5GZwtfA0b9uKBVxMCrUvwAAAAAAAPA\u002fa+VmVTsfwr9MtzwtOt\u002ftP6THLtukEtw\u002fGnWopALhhz9+J7WfNxTLP+JSePqIqYA\u002fd3l+dv\u002fYmD8hKRjbSzfqP4++c\u002fOSQZk\u002f0owQZaujtz\u002f9wColl+TKPwxknk4g5dk\u002fa+VmVTsfwr8AAAAAAADwP46VYPNSQ8S\u002f2yoMq2xvv7\u002ftuE5S1O+avxPajUll+Ma\u002f5mRfVUGz2r+c+pEkdLOKv\u002fUBVzjwQLC\u002fm1vdiI4Wez\u002fo0RnsbKvYv2tPNDUyMtm\u002fzVXrNRRB3b9MtzwtOt\u002ftP46VYPNSQ8S\u002fAAAAAAAA8D8=","shape":"13, 13"},"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[ ...

# %% [markdown]
# ### 4. Model set-up, training and evaluation
#
# The next step is to set-up the model. In this example we train a conditional variational autoencoder to be able to function both as a surrogate model (for an input X predicting Y) aswell as an performance-oriented generative model (for defined constraints for Y generate valid Xs).
#
# #### Set-up
#
# First we define the input and output of our model. In this case the inputs are our design parameters (X) and our outputs the performance attributes.

# %%
inputML = dataset.design_par.names_list
outputML = dataset.perf_attributes.names_list

# %% [markdown]
# Next, we need to create a datamodule from our dataset.

# %%
from aixd.mlmodel.data.data_loader import DataModule

datamodule = DataModule.from_dataset(dataset, input_ml_names=inputML, output_ml_names=outputML, batch_size=1000)
# Out:
# [INFO - AIXD.data-objects] * Updating domain for Concrete: OK (no update)

# %% [markdown]
# Now, we can define the structure of our model. We first import the model we want to train and then initialize this model from our datamodule. We here define the number of layers (here:3) and the individual widths of each layer (here: 16,8,4). Furthermore the number of latent dimensions has to be chosen (here:1).

# %%
from aixd.mlmodel.architecture.cond_ae_model import CondAEModel

loss_weights = {"x": 1.0, "y": 2, "kl": 0.1}
cae = CondAEModel.from_datamodule(datamodule, layer_widths=[512, 256, 128, 64, 32, 16], latent_dim=3, loss_weights=loss_weights)

# %% [markdown]
# #### Training
#
# Now that the model structure is set-up we train the model. Meaning we fit the model to our training data.Here we select to train maximum for 100 epochs and turn on early stopping.

# %%
import warnings

max_epochs = 20000

with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=UserWarning)
    cae.fit(datamodule, name_run="Run1", max_epochs=max_epochs, flag_early_stop=True)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name    | Type    | Params | Mode
# --------------------------------------------
# 0 | encoder | Encoder | 533 K  | train
# 1 | decoder | Decoder | 533 K  | train
# --------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.268     Total estimated model params size (MB)
# 213       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]

# %% [markdown]
# #### Evaluation
#
# The third step of this chapter is the evaluation of the before trained model. We first import the model and then visually evaluate it. The model evaluation is important, in order to discern how successful the training has been, and if the architecture may benefit from changes.
#
# To load the model we just need to provide the path to the checkpoint.

# %%
path = f"{CondAEModel.CHECKPOINT_DIR}/last.ckpt"
cae = CondAEModel.load_model_from_checkpoint(path)

# %% [markdown]
# To visually evaluate the trained model we have multiple helpful functionalities in the plotter. First we need to initialize the plotter again. This time additional to the dataset we also need to provide the model that we want to evaluate to the plotter object.

# %%
from aixd.visualisation.plotter import Plotter

plotter = Plotter(dataset=dataset, model=cae)
# Out:
# [INFO - AIXD.plotter]
# Plotter: Information
# --------------------
# The following block names and variable names are available as arguments for plotting methods:
#     Block "design_parameters" (Design Parameters):
#     -> Variables: "A", "mu", "sigma", "num_piers", "pier_h", "shell_cross_section", "pier_diameter", "Concrete"
#     Block "performance_attributes" (Performance Attributes):
#     -> Variables: "Nfrequ1", "Nfrequ2", "Nfrequ3", "max_disp_cm", "Mass_Kg", "util_average"
# Data from dataset blocks will be plotted in the original data domain.
# Data from datamodule blocks will be plotted in the transformed domain (if `transformed=True`) or in the original domain, but after transformations (if `transformed=False`).

# %% [markdown]
# The below figure shows the predicted values plotter against the true values from the validation dataset. A perfect fit would mean that all scatter points lie on the 45° line. By normalizing the data we archive the error in the original units.

# %%
plotter.attributes_obs_vs_pred(block="inputML", datamodule=datamodule, transformed=False, n_cols=2)
# Out:
# [INFO - AIXD.plotter] Overwriting datamodule with the provided one: {Train dataloader: size=800}
# {Validation dataloader: size=100}
# {Test dataloader: size=100}
# {Predict dataloader: None}
# /usr/local/lib/python3.12/dist-packages/aixd/mlmodel/data/data_loader.py:389: UserWarning:
#
# Batch size was adjusted from 1000 to 800 for training dataloader.
#
# /usr/local/lib/python3.12/dist-packages/aixd/mlmodel/data/data_loader.py:389: UserWarning:
#
# Batch size was adjusted from 1000 to 100 for validation dataloader.
#
# /usr/local/lib/python3.12/dist-packages/aixd/mlmodel/data/data_loader.py:389: UserWarning:
#
# Batch size was adjusted from 1000 to 100 for testing dataloader.
#
# /usr/local/lib/python3.12/dist-packages/aixd/mlmodel/data/data_loader.py:389: UserWarning:
#
# Batch size was adjusted from 1000 to 100 for validation dataloader.
#
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/setup.py:177: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="68d016aa-c779-4783-8874-05f9c851ac73" class="plotly-graph-div" style="height:1680px; width:1008.0px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("68d016aa-c779-4783-8874-05f9c851ac73")) {                    Plotly.newPlot(                        "68d016aa-c779-4783-8874-05f9c851ac73",                        [{"customdata":{"dtype":"f8","bdata":"cCuIHT5QCEDmqsLeRBwFQA=="},"hovertemplate":"(pred=%{x}, true=%{y}, error=%{customdata})","legend":"legend","legendgroup":"ranges","marker":{"color":"rgb(255,120,90)","line":{"color":"white","width":0.5},"size":5},"mode":"markers","name":"≤ 3.04","x":[1.8257005267330306,1.9707804405222376],"y":[4.864881502378162,4.6095836749237336],"type":"scatter","xaxis":"x","yaxis":"y"},{"customdata":{"dtype":"f8","bdata":
plotter.attributes_obs_vs_pred(block="outputML", datamodule=datamodule, transformed=False, n_cols=2)
# Out:
# [INFO - AIXD.plotter] Overwriting datamodule with the provided one: {Train dataloader: size=800}
# {Validation dataloader: size=100}
# {Test dataloader: size=100}
# {Predict dataloader: None}
# /usr/local/lib/python3.12/dist-packages/aixd/mlmodel/data/data_loader.py:389: UserWarning:
#
# Batch size was adjusted from 1000 to 800 for training dataloader.
#
# /usr/local/lib/python3.12/dist-packages/aixd/mlmodel/data/data_loader.py:389: UserWarning:
#
# Batch size was adjusted from 1000 to 100 for validation dataloader.
#
# /usr/local/lib/python3.12/dist-packages/aixd/mlmodel/data/data_loader.py:389: UserWarning:
#
# Batch size was adjusted from 1000 to 100 for testing dataloader.
#
# /usr/local/lib/python3.12/dist-packages/aixd/mlmodel/data/data_loader.py:389: UserWarning:
#
# Batch size was adjusted from 1000 to 100 for validation dataloader.
#
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/setup.py:177: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="089d9b35-c876-40dc-bdd0-54036ff34da5" class="plotly-graph-div" style="height:1260px; width:1008.0px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("089d9b35-c876-40dc-bdd0-54036ff34da5")) {                    Plotly.newPlot(                        "089d9b35-c876-40dc-bdd0-54036ff34da5",                        [{"customdata":{"dtype":"f8","bdata":"NDMzo8hl\u002fT8="},"hovertemplate":"(pred=%{x}, true=%{y}, error=%{customdata})","legend":"legend","legendgroup":"ranges","marker":{"color":"rgb(255,120,90)","line":{"color":"white","width":0.5},"size":5},"mode":"markers","name":"≤ 1.84","x":[2.0626504361629485],"y":[3.8999999821186067],"type":"scatter","xaxis":"x","yaxis":"y"},{"customdata":{"dtype":"f8","bdata":"MjMzv1H89T9mZmYa37vyPwAAALgJI\u002fI\u002f"},"hovertemplate":"(pred=%{x}, true=%{y}, error=%{customdata})","legend":"legend","legendgroup":"ranges","marker":{"color":"rgb(255,200,100)","line":{"color":"white","width":0.5},"size":5},"mode":"markers","name":"≤ 1.47","x":[3.325898411870003,3.029133024811745,3.0664458990097048],"y":[4.699999809265137,4.200000089406967,4.200000089406967],"type":"scatter","xaxis":"x","yaxis":"y"},{"customdata":{"dtype":"f8","bdata":"mpmZtfCi7z8AAABQ+GTwP87MzLCJkfE\u002fzsxMDz\u002fq6z8="},"hovertemplate":"(pred=%{x}, true=%{y}, error=%{customdata})","legend":"legend","legendgroup":"ranges","marker":{"color":"rgb(90,190,210)","line":{"color":"white","width":0.5},"size":5},"mode":"markers","name":"≤ 1.10","x":[1.6113598063588144,2.375349161028862,2.401968365907669,1.1723445221781732],"y":[2.5999999761581423,3.400000032782555,3.500000068545342,0.2999999998137355],"type":"scatter","xaxis":"x","yaxis":"y"},{"customdata":{"dtype":"f8","bdata":"mpkZmpyj4j\u002fMzMxUJi7fP2ZmZsYwEdk\u002fAAAAAMXh3T\u002fNzMw6QTzjPwAAAHCMM9g\u002fyMzM\u002fHXO2T80MzODpzblP87MzMAfAuI\u002fm5mZrxp25j8yMzP3H37iPwAAALBeR9s\u002fZmZmL0Ks2T8wMzNDyWPbPzgzMzNR8N8\u002fZmZm1miK4z9gZmaWGWrdP5iZmfnnhNg\u002fMzMz4U7E5D\u002fNzExneozfP9DMzPxKNds\u002fMDMzg1Hn4j\u002fMzMyEWG\u002fYP5mZmY63IeE\u002f0MzMXMha3T8wMzOTMZnbPw=="},"hovertemplate":"(pred=%{x}, true=%{y}, error=%{customdata})","legend
# %% [markdown]
# ### 5. Model deployment
#
# Once the model is trained and evaluated, it can be deployed to the respective design problem.
# Below we show how the trained model can be used to (i) inversely generate new samples based on defined constraints and (ii) evaluate a large amount of samples in quasi-real time.
#
# ##### (i) Inverse Design: Constrained Generation
#
# Our goal here is to use the trained model to generate new samples, while considering defined performance constraints.
#
# We here plot again the data distributions to know which perfromance ranges make sense to be requested.

# %%
plotter = Plotter(dataset=dataset, model=cae, datamodule=datamodule)
# Out:
# [INFO - AIXD.plotter]
# Plotter: Information
# --------------------
# The following block names and variable names are available as arguments for plotting methods:
#     Block "design_parameters" (Design Parameters):
#     -> Variables: "A", "mu", "sigma", "num_piers", "pier_h", "shell_cross_section", "pier_diameter", "Concrete"
#     Block "performance_attributes" (Performance Attributes):
#     -> Variables: "Nfrequ1", "Nfrequ2", "Nfrequ3", "max_disp_cm", "Mass_Kg", "util_average"
#     Block "inputML" (Input ML):
#     -> Variables: "A", "mu", "sigma", "num_piers", "pier_h", "shell_cross_section", "pier_diameter", "Concrete"
#     Block "outputML" (Output ML):
#     -> Variables: "Nfrequ1", "Nfrequ2", "Nfrequ3", "max_disp_cm", "Mass_Kg", "util_average"
# Data from dataset blocks will be plotted in the original data domain.
# Data from datamodule blocks will be plotted in the transformed domain (if `transformed=True`) or in the original domain, but after transformations (if `transformed=False`).

# %%
from aixd.mlmodel.generation.generator import Generator

gen = Generator(model=cae, datamodule=datamodule, over_sample=1)
# Out:
# [INFO - AIXD.mlmodel-generator]
# Generator: Information
# ----------------------
# To request designs, the following variables are available:
#     "Nfrequ1", "Nfrequ2", "Nfrequ3", "max_disp_cm", "Mass_Kg", "util_average"
# The generation process is set to: Fast
#     In this case, the values of z will not be generated conditioned on the y requested.
#     This vastly accelerates the generation process, and is compensated by the over_sample
#     parameter, which will allow generating more designs to then choose the best.

# %% [markdown]
# To make an example we want to generate samples which have an $Y_{2}$-value between 150 and 155. To execute this generation we first need to formulate this request in a dictionary, and then provide it to the generator. Here we chose to generate 1000 samples, and the output type DataFrame.

# %%
request = {"max_disp_cm": [1, 20]}

df_gen, _ = gen.generate(request, n_samples=1000, format_out="df")
df_gen
# Out:
# [INFO - AIXD.mlmodel-generator]
# Generator: Accuracy
# -------------------
# Requested attributes:               |              max_disp_cm |
# Requested values:                   |               [1.0-20.0] |
# Best generated sample:              |        14.07246011718584 |
# Mean error of generated samples:    |                    ----- |
#    .. of all returned 1000 samples: |    +/- 47.48159784950985 |
#         .. of the best 100 samples: |                  +/- 0.0 |
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/setup.py:177: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/setup.py:177: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
#             A        mu     sigma num_piers    pier_h shell_cross_section  \
# 259  3.344671  0.369633    0.5221         4 -4.982809           22.427115
# 807  2.554849  0.632154  0.753833         3 -4.052552           22.820675
# 802  2.506765   0.34361  0.403988         3 -5.113029           15.962207
# 800  3.274673  0.765447   0.74549         4 -4.470017            21.50732
# 792  3.869749  0.760273  0.560224         1 -4.111242            24.01307
# ..        ...       ...       ...       ...       ...                 ...
# 648  3.076836  0.003128  0.092575         4 -4.640459           28.506292
# 251  3.003304   0.66018  0.207118         0 -2.366801           24.177798
# 715  1.296395  0.036938   0.72985         1 -3.642746           26.955187
# 810  2.364838  0.238426  0.100033         2 -3.241474           18.526587
# 544  2.611901   0.08586  0.129943         2 -3.518037           24.995462
#
#     pier_diameter Concrete   Nfrequ1   Nfrequ2   Nfrequ3 max_disp_cm  \
# 259     37.475027   C60/75  1.643673  3.145494  5.739649    14.07246
# 807     40.635185   C30/37  1.699438  2.828983  4.823036    18.08023
# 802     37.024301   C60/75  1.408858  2.413623  4.039226   15.325965
# 800     38.121696   C30/37  1.625581  2.914202  5.136314    7.013287
# 792     36.014141   C30/37  1.073683  1.820357  3.324385   13.061458
# ..            ...      ...       ...       ...       ...         ...
# 648     50.749888   C40/50  1.922692  3.036273  4.519721  337.841544
# 251     36.182877   C40/50  1.026937  1.142403  1.606578   346.58619
# 715     48.530185   C40/50  1.447958  1.967502  3.284518  359.628618
# 810     37.082703   C40/50  1.520147  1.851007  2.226084  413.069246
# 544     42.286165   C40/50  1.618702  1.920146  2.565321  738.662283
#
#            Mass_Kg util_average
# 259  240672.400413     0.881571
# 807  232208.553548     0.776335
# 802  155445.600725      1.06982
# 800  231242.067821     0.467191
# 792  251497.648777     0.738835
# ..             ...          ...
# 648  262525.470675     5.330346
# 251  198900.161113     6.005024
# 715  234362.965107     8.125037
# 810  139620.763759     6.269379
# 544  213795.553014     9.755548
#
# [1000 rows x 14 columns]

# %%
df_gen.to_csv("inverseDesign1.csv", index=False)

# %% [markdown]
# Furthermore, we can not only condition on a single attribute, but on multiple attributes at the same time.

# %%
request = {"max_disp_cm": [0, 10], "Nfrequ1": [3, 5]}

df_gen, _ = gen.generate(request, n_samples=1000, format_out="df")
df_gen
# Out:
# [INFO - AIXD.mlmodel-generator]
# Generator: Accuracy
# -------------------
# Requested attributes:               |              max_disp_cm |                  Nfrequ1 |
# Requested values:                   |               [0.0-10.0] |                [3.0-5.0] |
# Best generated sample:              |       20.412407104118614 |        3.096536186337471 |
# Mean error of generated samples:    |                    ----- |                    ----- |
#    .. of all returned 1000 samples: |    +/- 64.91502620788644 |   +/- 1.5037401091426623 |
#         .. of the best 100 samples: |    +/- 59.96672826171476 |                  +/- 0.0 |
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/setup.py:177: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/setup.py:177: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
#             A        mu     sigma num_piers    pier_h shell_cross_section  \
# 231  3.644562  0.884701  0.501986         6 -1.283794           16.834555
# 330  2.488506  0.515096  0.276671         6 -0.925314           11.945428
# 457  3.286652   0.61114  0.207365         6 -0.911456           15.194681
# 577  4.386275  0.794018  0.212091         6 -1.002257           24.160681
# 850  2.095602  0.792784  0.735477         5 -2.216406           12.468026
# ..        ...       ...       ...       ...       ...                 ...
# 602  2.348335   0.07556   0.33152         1 -4.190225           13.874762
# 591  1.549462  0.018879   0.46766         1 -4.372426           17.745744
# 395  1.157948  0.266139   0.54249         0 -0.630681           16.918433
# 811  1.166813  0.287455   0.73649         0 -0.302906           26.743431
# 427  0.748481  0.134458  0.702161         0 -0.210588            19.02779
#
#     pier_diameter Concrete   Nfrequ1   Nfrequ2   Nfrequ3 max_disp_cm  \
# 231     44.543397   C30/37  3.096536  4.832264  6.402505   20.412407
# 330     39.258145   C30/37  3.153573  4.538895  5.225491   22.714701
# 457     39.251173   C30/37  3.174279  4.659665  5.576954   24.736117
# 577     42.275121   C30/37  3.125268  4.935778  6.871152   26.115629
# 850     48.103783   C60/75  3.084792  4.490998  5.767382   32.091931
# ..            ...      ...       ...       ...       ...         ...
# 602     37.225138   C60/75  1.113795  1.464095  2.139709   54.344035
# 591     40.947142   C40/50  1.227952  1.426417  1.996733  389.068214
# 395     42.385614   C60/75    1.0703  1.120105   1.40267  214.761333
# 811     42.386322   C60/75  1.019945   1.40098  2.097401  174.379295
# 427      41.01862   C60/75  1.043188  1.099615  1.431656  223.318909
#
#            Mass_Kg util_average
# 231  186830.290346     0.578225
# 330  114448.341266     0.609924
# 457  142341.913422     0.637798
# 577  247550.757812     0.721304
# 850   134291.75588     1.047517
# ..             ...          ...
# 602  122502.995115     2.025034
# 591  147284.495531     7.011226
# 395  113602.192896     4.272183
# 811  195939.126073     4.904423
# 427  117951.894398     4.813764
#
# [1000 rows x 14 columns]

# %%
df_gen.to_csv("inverseDesign2.csv", index=False)

# %% [markdown]
# ##### (ii) Forward Design: Predictions
#
# We can also use the encoder model to evaluate a large amount of samples in quasi-real time. This can be beneficial for example for the optimisation of a design.
#
#
# To show this functionality we here import a large amount of design parameter vectors from a csv file to be evaluated by the trained encoder

# %%
df_pred = cae.forward_evaluation(df_samples[:5].to_numpy(), format_out="df", input_transformed=False, return_untransformed=True)
df_pred
# Out:
#     Nfrequ1   Nfrequ2   Nfrequ3  max_disp_cm        Mass_Kg  util_average
# 0  1.175091  1.680325  2.124423   227.313585  173606.701515      4.006581
# 1  1.091749  1.860063  3.621876    17.780638  274761.276245      0.874415
# 2  2.481823  4.343407  6.491078    10.531953  208512.341127      0.446061
# 3  2.881702  4.786360  6.842879    48.462469  188220.392623      1.162115
# 4  1.111687  1.450033  2.277105    66.558211  128606.379937      2.550279

# %% [markdown]
# ### 6.  Sensitivity analysis
#
# The sensitivity of performance attributes at different design points is evaluated using the local and global sensitivity analysis features. In the first case, the sensitivity of user specified performance attributes is calculated at specific points in the design space, while in the context of global sensitivity analysis, the distribution of sensitivities is extracted from a number of different design points.
#
# The extraction of sensitivities, requires the specification of the following inputs:
#
# - the design point(s), at which the sensitivity is calculated
# - the performance attribute, for which the sensitivity with respect to all design parameters is calculated

# %%
from aixd.mlmodel.sensitivity.sensitivities import LocalSensitivity, GlobalSensitivity
import torch

# %% [markdown]
# ##### 6.1 Local Sensitivity

# %%
local_sensitivity = LocalSensitivity(cae)

# Calculating the local sensitivity
x = torch.tensor(datamodule.x_test, requires_grad=True)
x_truncated = x[5:6, :].detach().requires_grad_(True)
sensitivities = local_sensitivity.calculate(x_truncated, ["max_disp_cm", "Nfrequ1"])

# Plotting the local sensitivity
local_sensitivity.plot(x_truncated, "max_disp_cm")

# Plotting the local sensitivity
x_truncated = x[11:12, :].detach().requires_grad_(True)
local_sensitivity.plot(x_truncated, "Nfrequ1")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="c399efcd-ac18-49be-80bf-bf0c14a2b07b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c399efcd-ac18-49be-80bf-bf0c14a2b07b")) {                    Plotly.newPlot(                        "c399efcd-ac18-49be-80bf-bf0c14a2b07b",                        [{"marker":{"color":["#643264","#5abed2","#466ea0","#ffc864","#ff785a","#8ce6e6","#5aa0a0","#aa50a0","#aa50a0"],"line":{"color":["#643264","#5abed2","#466ea0","#ffc864","#ff785a","#8ce6e6","#5aa0a0","#aa50a0","#aa50a0"],"width":1}},"name":"Local Sensitivity","orientation":"h","x":[0.13219064474105835,-0.14060470461845398,0.07514351606369019,0.41583311557769775,0.1538158506155014,-0.06552151590585709,0.2932499349117279,-0.011909689754247665,-0.011945592239499092],"y":["A","mu","sigma","num_piers","pier_h","shell_cross_section","pier_diameter","Concrete = C30\u002f37","Concrete = C60\u002f75"],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","s ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="1824c10c-57c1-4386-a3d5-2f4c0ba1ef2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1824c10c-57c1-4386-a3d5-2f4c0ba1ef2a")) {                    Plotly.newPlot(                        "1824c10c-57c1-4386-a3d5-2f4c0ba1ef2a",                        [{"marker":{"color":["#643264","#5abed2","#466ea0","#ffc864","#ff785a","#8ce6e6","#5aa0a0","#aa50a0","#aa50a0"],"line":{"color":["#643264","#5abed2","#466ea0","#ffc864","#ff785a","#8ce6e6","#5aa0a0","#aa50a0","#aa50a0"],"width":1}},"name":"Local Sensitivity","orientation":"h","x":[-0.07663038372993469,-0.04184497147798538,0.05666232109069824,0.15944638848304749,0.31565794348716736,-0.05336089804768562,0.18235839903354645,-0.022563934326171875,-0.0171489417552948],"y":["A","mu","sigma","num_piers","pier_h","shell_cross_section","pier_diameter","Concrete = C30\u002f37","Concrete = C40\u002f50"],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay"," ...

# %% [markdown]
# ##### 6.2 Global Sensitivity

# %%
global_sensitivity = GlobalSensitivity(cae)

# Calculating the global sensitivity
x = torch.tensor(datamodule.x_test, requires_grad=True)
global_sensitivity_max_disp = global_sensitivity.calculate(x, "max_disp_cm")

# Plotting the global sensitivity of MaxDisp and Nfrequ1
global_sensitivity.plot(x, ["max_disp_cm", "Nfrequ1"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="96e58e47-8147-41c6-b445-ff1b30c82a08" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("96e58e47-8147-41c6-b445-ff1b30c82a08")) {                    Plotly.newPlot(                        "96e58e47-8147-41c6-b445-ff1b30c82a08",                        [{"boxpoints":"all","jitter":0.0,"line":{"width":1},"marker":{"color":"#643264","size":2},"name":"A","whiskerwidth":0.5,"x":[-0.0011065286817029119,-0.0003617811016738415,-0.0009266756824217737,-0.006648549344390631,-0.0063325571827590466,-0.0054999664425849915,-0.023830967023968697,-0.0007422929629683495,0.00013157188368495554,-0.002476745517924428,-0.0024244666565209627,-0.0028353012166917324,-0.03935445472598076,-0.002328987931832671,-0.0039572883397340775,-0.0020500370301306248,-0.010440077632665634,-0.0029726328793913126,-0.007552518509328365,-0.0013442945200949907,-0.0010997419012710452,0